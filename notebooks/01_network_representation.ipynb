# %% [markdown]
# # Task 1: Network Representation
#
# This notebook explores the representation of the air transport network.
#
# ## Objectives
# - Load and explore the airline network data
# - Create network graph representations
# - Calculate basic network properties
# - Visualize the network structure

# %%
# Import required libraries
import sys
sys.path.append('../src')

import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from network_representation import *

# Set visualization style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 8)

# %% [markdown]
# ## 1. Load Data
#
# TODO: Load the air transport network data

# %%
# Load network data
# data = load_network_data('../data/raw/airports.csv')

# %% [markdown]
# ## 2. Create Network Graph
#
# TODO: Create a graph representation of the network

# %%
# Create network graph
# graph = create_network_graph(data)

# %% [markdown]
# ## 3. Network Properties
#
# TODO: Calculate and analyze basic network properties

# %%
# Calculate network properties
# properties = calculate_network_properties(graph)
# print(properties)

# %% [markdown]
# ## 4. Visualization
#
# TODO: Visualize the network

# %%
# Visualize the network
# plt.figure(figsize=(15, 10))
# nx.draw(graph, with_labels=True)
# plt.title('Air Transport Network')
# plt.show()
